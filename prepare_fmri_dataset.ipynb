# %%
#from google.colab import drive
#drive.mount('/content/drive')
#%cd drive/MyDrive/MesDossiers/Master CNN/supervised_project/FMRI_ADHD_Classification

# %%
# %%capture
#!pip install nilearn

# %%
import os
import pandas as pd
import urllib.request

# Configuration
pipeline = 'cpac'
strategy = 'filt_global'
derivative = 'func_preproc'
output_dir = "Fmri_Data"
sites = ["NYU"] # Choose the site
num_scans_per_site = 100  # Limit to 10 scans for testing

# URL details for ABIDE
base_url = "https://fcp-indi.s3.amazonaws.com/data/Projects/ABIDE_Initiative/Outputs/"
phenotype_url = "https://fcp-indi.s3.amazonaws.com/data/Projects/ABIDE_Initiative/Phenotypic_V1_0b_preprocessed1.csv"

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Download phenotype data
phenotype_path = os.path.join(output_dir, "Phenotypic_V1_0b_preprocessed1.csv")
if not os.path.exists(phenotype_path):
    urllib.request.urlretrieve(phenotype_url, phenotype_path)

# Load the phenotype data
phenotypes = pd.read_csv(phenotype_path)

# Process data for each site
for site in sites:
    site_dir = os.path.join(output_dir, site)
    os.makedirs(site_dir, exist_ok=True)

    # Filter data by site and limit the number of scans
    site_data = phenotypes[phenotypes['SITE_ID'] == site].head(num_scans_per_site)

    # Save the site's phenotypic CSV
    site_pheno_path = os.path.join(site_dir, f"{site}_phenotypic.csv")
    site_data.to_csv(site_pheno_path, index=False)

    # Download each scan
    for _, row in site_data.iterrows():
        file_id = row['FILE_ID']
        numeric_id = file_id.split('_')[-1]  # Extract the numeric part

        # Create directory for each scan
        scan_dir = os.path.join(site_dir, numeric_id)
        os.makedirs(scan_dir, exist_ok=True)

        # Download the .nii.gz file for each scan
        filename = f"{file_id}_{derivative}.nii.gz"
        download_url = f"{base_url}{pipeline}/{strategy}/{derivative}/{filename}"
        local_file_path = os.path.join(scan_dir, filename)

        # Download if not already present
        if not os.path.exists(local_file_path):
            try:
                print(f"Downloading {filename} for subject {numeric_id}")
                urllib.request.urlretrieve(download_url, local_file_path)
                print(f"Downloaded: {filename}")
            except urllib.error.HTTPError as e:
                print(f"Error downloading {filename}: {e}")
        else:
            print(f"{filename} already exists, skipping download.")
# Out:
# NYU_0050952_func_preproc.nii.gz already exists, skipping download.
# Downloading no_filename_func_preproc.nii.gz for subject filename
# Error downloading no_filename_func_preproc.nii.gz: HTTP Error 404: Not Found
# NYU_0050954_func_preproc.nii.gz already exists, skipping download.
# NYU_0050955_func_preproc.nii.gz already exists, skipping download.
# NYU_0050956_func_preproc.nii.gz already exists, skipping download.
# NYU_0050957_func_preproc.nii.gz already exists, skipping download.
# NYU_0050958_func_preproc.nii.gz already exists, skipping download.
# NYU_0050959_func_preproc.nii.gz already exists, skipping download.
# NYU_0050960_func_preproc.nii.gz already exists, skipping download.
# NYU_0050961_func_preproc.nii.gz already exists, skipping download.
# Downloading NYU_0050962_func_preproc.nii.gz for subject 0050962
# Downloaded: NYU_0050962_func_preproc.nii.gz
# Downloading NYU_0050964_func_preproc.nii.gz for subject 0050964
# Downloaded: NYU_0050964_func_preproc.nii.gz
# Downloading NYU_0050965_func_preproc.nii.gz for subject 0050965
# Downloaded: NYU_0050965_func_preproc.nii.gz
# Downloading NYU_0050966_func_preproc.nii.gz for subject 0050966
# Downloaded: NYU_0050966_func_preproc.nii.gz
# Downloading NYU_0050967_func_preproc.nii.gz for subject 0050967
# Downloaded: NYU_0050967_func_preproc.nii.gz
# Downloading NYU_0050968_func_preproc.nii.gz for subject 0050968
# Downloaded: NYU_0050968_func_preproc.nii.gz
# Downloading NYU_0050969_func_preproc.nii.gz for subject 0050969
# Downloaded: NYU_0050969_func_preproc.nii.gz
# Downloading NYU_0050970_func_preproc.nii.gz for subject 0050970
# Downloaded: NYU_0050970_func_preproc.nii.gz
# Downloading no_filename_func_preproc.nii.gz for subject filename
# Error downloading no_filename_func_preproc.nii.gz: HTTP Error 404: Not Found
# Downloading NYU_0050972_func_preproc.nii.gz for subject 0050972
# Downloaded: NYU_0050972_func_preproc.nii.gz
# Downloading NYU_0050973_func_preproc.nii.gz for subject 0050973
# Downloaded: NYU_0050973_func_preproc.nii.gz
# Downloading NYU_0050974_func_preproc.nii.gz for subject 0050974
# Downloaded: NYU_0050974_func_preproc.nii.gz
# Downloading no_filename_func_preproc.nii.gz for subject filename
# Error downloading no_filename_func_preproc.nii.gz: HTTP Error 404: Not Found
# Downloading NYU_0050976_func_preproc.nii.gz for subject 0050976
# Downloaded: NYU_0050976_func_preproc.nii.gz
# Downloading NYU_0050977_func_preproc.nii.gz for subject 0050977
# Downloaded: NYU_0050977_func_preproc.nii.gz
# Downloading NYU_0050978_func_preproc.nii.gz for subject 0050978
# Downloaded: NYU_0050978_func_preproc.nii.gz
# Downloading NYU_0050979_func_preproc.nii.gz for subject 0050979
# Downloaded: NYU_0050979_func_preproc.nii.gz
# Downloading no_filename_func_preproc.nii.gz for subject filename
# Error downloading no_filename_func_preproc.nii.gz: HTTP Error 404: Not Found
# Downloading NYU_0050981_func_preproc.nii.gz for subject 0050981
# Downloaded: NYU_0050981_func_preproc.nii.gz
# Downloading NYU_0050982_func_preproc.nii.gz for subject 0050982
# Downloaded: NYU_0050982_func_preproc.nii.gz
# Downloading NYU_0050983_func_preproc.nii.gz for subject 0050983
# Downloaded: NYU_0050983_func_preproc.nii.gz
# Downloading NYU_0050984_func_preproc.nii.gz for subject 0050984
# Downloaded: NYU_0050984_func_preproc.nii.gz
# Downloading NYU_0050985_func_preproc.nii.gz for subject 0050985
# Downloaded: NYU_0050985_func_preproc.nii.gz
# Downloading NYU_0050986_func_preproc.nii.gz for subject 0050986
# Downloaded: NYU_0050986_func_preproc.nii.gz
# Downloading NYU_0050987_func_preproc.nii.gz for subject 0050987
# Downloaded: NYU_0050987_func_preproc.nii.gz
# Downloading NYU_0050988_func_preproc.nii.gz for subject 0050988
# Downloaded: NYU_0050988_func_preproc.nii.gz
# Downloading NYU_0050989_func_preproc.nii.gz for subject 0050989
# Downloaded: NYU_0050989_func_preproc.nii.gz
# Downloading NYU_0050990_func_preproc.nii.gz for subject 0050990
# Downloaded: NYU_0050990_func_preproc.nii.gz
# Downloading NYU_0050991_func_preproc.nii.gz for subject 0050991
# Downloaded: NYU_0050991_func_preproc.nii.gz
# Downloading NYU_0050992_func_preproc.nii.gz for subject 0050992
# Downloaded: NYU_0050992_func_preproc.nii.gz
# Downloading NYU_0050993_func_preproc.nii.gz for subject 0050993
# Downloaded: NYU_0050993_func_preproc.nii.gz
# Downloading NYU_0050994_func_preproc.nii.gz for subject 0050994
# Downloaded: NYU_0050994_func_preproc.nii.gz
# Downloading NYU_0050995_func_preproc.nii.gz for subject 0050995
# Downloaded: NYU_0050995_func_preproc.nii.gz
# Downloading NYU_0050996_func_preproc.nii.gz for subject 0050996
# Downloaded: NYU_0050996_func_preproc.nii.gz
# Downloading NYU_0050997_func_preproc.nii.gz for subject 0050997
# Downloaded: NYU_0050997_func_preproc.nii.gz
# Downloading NYU_0050998_func_preproc.nii.gz for subject 0050998
# Downloaded: NYU_0050998_func_preproc.nii.gz
# Downloading NYU_0050999_func_preproc.nii.gz for subject 0050999
# Downloaded: NYU_0050999_func_preproc.nii.gz
# Downloading NYU_0051000_func_preproc.nii.gz for subject 0051000
# Downloaded: NYU_0051000_func_preproc.nii.gz
# Downloading NYU_0051001_func_preproc.nii.gz for subject 0051001
# Downloaded: NYU_0051001_func_preproc.nii.gz
# Downloading NYU_0051002_func_preproc.nii.gz for subject 0051002
# Downloaded: NYU_0051002_func_preproc.nii.gz
# Downloading NYU_0051003_func_preproc.nii.gz for subject 0051003
# Downloaded: NYU_0051003_func_preproc.nii.gz
# Downloading NYU_0051006_func_preproc.nii.gz for subject 0051006
# Downloaded: NYU_0051006_func_preproc.nii.gz
# Downloading NYU_0051007_func_preproc.nii.gz for subject 0051007
# Downloaded: NYU_0051007_func_preproc.nii.gz
# Downloading NYU_0051008_func_preproc.nii.gz for subject 0051008
# Downloaded: NYU_0051008_func_preproc.nii.gz
# Downloading NYU_0051009_func_preproc.nii.gz for subject 0051009
# Downloaded: NYU_0051009_func_preproc.nii.gz
# Downloading NYU_0051010_func_preproc.nii.gz for subject 0051010
# Downloaded: NYU_0051010_func_preproc.nii.gz
# Downloading NYU_0051011_func_preproc.nii.gz for subject 0051011
# Downloaded: NYU_0051011_func_preproc.nii.gz
# Downloading NYU_0051012_func_preproc.nii.gz for subject 0051012
# Downloaded: NYU_0051012_func_preproc.nii.gz
# Downloading NYU_0051013_func_preproc.nii.gz for subject 0051013
# Downloaded: NYU_0051013_func_preproc.nii.gz
# Downloading NYU_0051014_func_preproc.nii.gz for subject 0051014
# Downloaded: NYU_0051014_func_preproc.nii.gz
# Downloading NYU_0051015_func_preproc.nii.gz for subject 0051015
# Downloaded: NYU_0051015_func_preproc.nii.gz
# Downloading NYU_0051016_func_preproc.nii.gz for subject 0051016
# Downloaded: NYU_0051016_func_preproc.nii.gz
# Downloading NYU_0051017_func_preproc.nii.gz for subject 0051017
# Downloaded: NYU_0051017_func_preproc.nii.gz
# Downloading NYU_0051018_func_preproc.nii.gz for subject 0051018
# Downloaded: NYU_0051018_func_preproc.nii.gz
# Downloading NYU_0051019_func_preproc.nii.gz for subject 0051019
# Downloaded: NYU_0051019_func_preproc.nii.gz
# Downloading NYU_0051020_func_preproc.nii.gz for subject 0051020
# Downloaded: NYU_0051020_func_preproc.nii.gz
# Downloading NYU_0051021_func_preproc.nii.gz for subject 0051021
# Downloaded: NYU_0051021_func_preproc.nii.gz
# Downloading NYU_0051023_func_preproc.nii.gz for subject 0051023
# Downloaded: NYU_0051023_func_preproc.nii.gz
# Downloading NYU_0051024_func_preproc.nii.gz for subject 0051024
# Downloaded: NYU_0051024_func_preproc.nii.gz
# Downloading NYU_0051025_func_preproc.nii.gz for subject 0051025
# Downloaded: NYU_0051025_func_preproc.nii.gz
# Downloading NYU_0051026_func_preproc.nii.gz for subject 0051026
# Downloaded: NYU_0051026_func_preproc.nii.gz
# Downloading NYU_0051027_func_preproc.nii.gz for subject 0051027
# Downloaded: NYU_0051027_func_preproc.nii.gz
# Downloading NYU_0051028_func_preproc.nii.gz for subject 0051028
# Downloaded: NYU_0051028_func_preproc.nii.gz
# Downloading NYU_0051029_func_preproc.nii.gz for subject 0051029
# Downloaded: NYU_0051029_func_preproc.nii.gz
# Downloading NYU_0051030_func_preproc.nii.gz for subject 0051030
# Downloaded: NYU_0051030_func_preproc.nii.gz
# Downloading NYU_0051032_func_preproc.nii.gz for subject 0051032
# Downloaded: NYU_0051032_func_preproc.nii.gz
# Downloading NYU_0051033_func_preproc.nii.gz for subject 0051033
# Downloaded: NYU_0051033_func_preproc.nii.gz
# Downloading NYU_0051034_func_preproc.nii.gz for subject 0051034
# Downloaded: NYU_0051034_func_preproc.nii.gz
# Downloading NYU_0051035_func_preproc.nii.gz for subject 0051035
# Downloaded: NYU_0051035_func_preproc.nii.gz
# Downloading NYU_0051036_func_preproc.nii.gz for subject 0051036
# Downloaded: NYU_0051036_func_preproc.nii.gz
# Downloading NYU_0051038_func_preproc.nii.gz for subject 0051038
# Downloaded: NYU_0051038_func_preproc.nii.gz
# Downloading NYU_0051039_func_preproc.nii.gz for subject 0051039
# Downloaded: NYU_0051039_func_preproc.nii.gz
# Downloading NYU_0051040_func_preproc.nii.gz for subject 0051040
# Downloaded: NYU_0051040_func_preproc.nii.gz
# Downloading NYU_0051041_func_preproc.nii.gz for subject 0051041
# Downloaded: NYU_0051041_func_preproc.nii.gz
# Downloading NYU_0051042_func_preproc.nii.gz for subject 0051042
# Downloaded: NYU_0051042_func_preproc.nii.gz
# Downloading NYU_0051044_func_preproc.nii.gz for subject 0051044
# Downloaded: NYU_0051044_func_preproc.nii.gz
# Downloading NYU_0051045_func_preproc.nii.gz for subject 0051045
# Downloaded: NYU_0051045_func_preproc.nii.gz
# Downloading NYU_0051046_func_preproc.nii.gz for subject 0051046
# Downloaded: NYU_0051046_func_preproc.nii.gz
# Downloading NYU_0051047_func_preproc.nii.gz for subject 0051047
# Downloaded: NYU_0051047_func_preproc.nii.gz
# Downloading NYU_0051048_func_preproc.nii.gz for subject 0051048
# Downloaded: NYU_0051048_func_preproc.nii.gz
# Downloading NYU_0051049_func_preproc.nii.gz for subject 0051049
# Downloaded: NYU_0051049_func_preproc.nii.gz
# Downloading NYU_0051050_func_preproc.nii.gz for subject 0051050
# Downloaded: NYU_0051050_func_preproc.nii.gz
# Downloading NYU_0051051_func_preproc.nii.gz for subject 0051051
# Downloaded: NYU_0051051_func_preproc.nii.gz
# Downloading NYU_0051052_func_preproc.nii.gz for subject 0051052
# Downloaded: NYU_0051052_func_preproc.nii.gz
# Downloading NYU_0051053_func_preproc.nii.gz for subject 0051053
# Downloaded: NYU_0051053_func_preproc.nii.gz
# Downloading NYU_0051054_func_preproc.nii.gz for subject 0051054
# Downloaded: NYU_0051054_func_preproc.nii.gz
# Downloading NYU_0051055_func_preproc.nii.gz for subject 0051055
# Downloaded: NYU_0051055_func_preproc.nii.gz
# Downloading NYU_0051056_func_preproc.nii.gz for subject 0051056
# Downloaded: NYU_0051056_func_preproc.nii.gz
# Downloading NYU_0051057_func_preproc.nii.gz for subject 0051057
# Downloaded: NYU_0051057_func_preproc.nii.gz
# Downloading NYU_0051058_func_preproc.nii.gz for subject 0051058
# Downloaded: NYU_0051058_func_preproc.nii.gz

# %%
import os
import pandas as pd
import shutil
import glob

# Define paths
dataset_directory = "Fmri_Data"  # Source directory with fMRI data
output_folder = "Extracted_Fmri_Data"  # Destination directory for consolidated files
os.makedirs(output_folder, exist_ok=True)  # Ensure output directory exists

# Initialize dataset tracker
dataset_tracker = {"Name": [], "DX": [], "Loc": []}

# Load phenotype data for each site and copy .nii.gz files
for site_folder in glob.glob(os.path.join(dataset_directory, "*")):
    site_name = os.path.basename(site_folder)
    pheno_csv_path = os.path.join(site_folder, f"{site_name}_phenotypic.csv")

    if os.path.exists(pheno_csv_path):
        pheno_data = pd.read_csv(pheno_csv_path)

        for scan_folder in glob.glob(os.path.join(site_folder, "*")):
            if os.path.isdir(scan_folder):
                # Use only the scan ID part for naming
                scan_id = os.path.basename(scan_folder)
                gz_file = glob.glob(os.path.join(scan_folder, "*.nii.gz"))
                print(gz_file)

                if gz_file:
                    # Construct filename and copy file
                    gz_filename = f"{scan_id}.nii.gz"  # Simplified filename with only scan ID
                    destination_path = os.path.join(output_folder, gz_filename)
                    shutil.copy(gz_file[0], destination_path)

                    # Record phenotype data
                    pheno_row = pheno_data[pheno_data['FILE_ID'].str.contains(scan_id)]
                    if not pheno_row.empty:
                        dx_value = pheno_row['DX_GROUP'].values[0]
                        dataset_tracker["Name"].append(gz_filename)
                        dataset_tracker["DX"].append(dx_value)
                        dataset_tracker["Loc"].append(destination_path)

# Convert tracker to DataFrame and save as Total_Data_Pheno.csv
df_total = pd.DataFrame(dataset_tracker)
df_total.to_csv(os.path.join(output_folder, "Total_Data_Pheno.csv"), index=False)

# Split into training and validation sets
df_total = df_total.sample(frac=1).reset_index(drop=True)  # Shuffle data
split_index = int(0.8 * len(df_total))  # 80% train, 20% validation
df_train = df_total.iloc[:split_index]
df_val = df_total.iloc[split_index:]

# Save training and validation DataFrames
df_train.to_csv(os.path.join(output_folder, "Training_Data_Pheno.csv"), index=False)
df_val.to_csv(os.path.join(output_folder, "Validation_Data_Pheno.csv"), index=False)

# Display results
print("Files copied to:", output_folder)
print("Total data entries:", len(df_total))
print("Training entries:", len(df_train))
print("Validation entries:", len(df_val))
# Out:
# ['Fmri_Data/NYU/0050952/NYU_0050952_func_preproc.nii.gz']
# []
# ['Fmri_Data/NYU/0050954/NYU_0050954_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050955/NYU_0050955_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050956/NYU_0050956_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050957/NYU_0050957_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050958/NYU_0050958_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050959/NYU_0050959_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050960/NYU_0050960_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050961/NYU_0050961_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050962/NYU_0050962_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050964/NYU_0050964_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050965/NYU_0050965_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050966/NYU_0050966_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050967/NYU_0050967_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050968/NYU_0050968_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050969/NYU_0050969_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050970/NYU_0050970_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050972/NYU_0050972_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050973/NYU_0050973_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050974/NYU_0050974_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050976/NYU_0050976_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050977/NYU_0050977_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050978/NYU_0050978_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050979/NYU_0050979_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050981/NYU_0050981_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050982/NYU_0050982_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050983/NYU_0050983_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050984/NYU_0050984_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050985/NYU_0050985_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050986/NYU_0050986_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050987/NYU_0050987_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050988/NYU_0050988_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050989/NYU_0050989_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050990/NYU_0050990_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050991/NYU_0050991_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050992/NYU_0050992_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050993/NYU_0050993_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050994/NYU_0050994_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050995/NYU_0050995_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050996/NYU_0050996_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050997/NYU_0050997_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050998/NYU_0050998_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0050999/NYU_0050999_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051000/NYU_0051000_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051001/NYU_0051001_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051002/NYU_0051002_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051003/NYU_0051003_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051006/NYU_0051006_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051007/NYU_0051007_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051008/NYU_0051008_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051009/NYU_0051009_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051010/NYU_0051010_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051011/NYU_0051011_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051012/NYU_0051012_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051013/NYU_0051013_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051014/NYU_0051014_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051015/NYU_0051015_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051016/NYU_0051016_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051017/NYU_0051017_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051018/NYU_0051018_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051019/NYU_0051019_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051020/NYU_0051020_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051021/NYU_0051021_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051023/NYU_0051023_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051024/NYU_0051024_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051025/NYU_0051025_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051026/NYU_0051026_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051027/NYU_0051027_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051028/NYU_0051028_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051029/NYU_0051029_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051030/NYU_0051030_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051032/NYU_0051032_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051033/NYU_0051033_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051034/NYU_0051034_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051035/NYU_0051035_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051036/NYU_0051036_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051038/NYU_0051038_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051039/NYU_0051039_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051040/NYU_0051040_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051041/NYU_0051041_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051042/NYU_0051042_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051044/NYU_0051044_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051045/NYU_0051045_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051046/NYU_0051046_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051047/NYU_0051047_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051048/NYU_0051048_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051049/NYU_0051049_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051050/NYU_0051050_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051051/NYU_0051051_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051052/NYU_0051052_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051053/NYU_0051053_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051054/NYU_0051054_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051055/NYU_0051055_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051056/NYU_0051056_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051057/NYU_0051057_func_preproc.nii.gz']
# ['Fmri_Data/NYU/0051058/NYU_0051058_func_preproc.nii.gz']
# Files copied to: Extracted_Fmri_Data
# Total data entries: 96
# Training entries: 76
# Validation entries: 20
